# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
#Change the base path before executing code
Base_path = "/home/tennistetris/Documents/Data Analytics/Hall/Inter_hall"
data = "DA_original_files"
Path_to_data = os.path.join(Base_path,data)
files = os.listdir(Path_to_data)
os.chdir(Path_to_data)

# %%
db = pd.read_csv('MF_IIT_DATA_V3.csv')
db.head()
# Out:
#    Serial_No                                          Fund_Name  \
# 0          1  Aditya Birla Sun Life Banking And Financial Se...
# 1          2  Aditya Birla Sun Life Frontline Equity Fund - ...
# 2          3  Aditya Birla Sun Life New Millennium Fund - Di...
# 3          4  Aditya Birla Sun Life Top 100 Fund - Direct Pl...
# 4          5              HDFC Large Cap Fund - Direct Plan (G)
#
#                           Fund_Family                  Fund_Class    Plan  \
# 0  Aditya Birla Sun Life Mutual Fund   Sector - Banking & Finance  Direct
# 1  Aditya Birla Sun Life Mutual Fund                    Large Cap  Direct
# 2  Aditya Birla Sun Life Mutual Fund          Sector - Technology  Direct
# 3  Aditya Birla Sun Life Mutual Fund                    Large Cap  Direct
# 4                    HDFC Mutual Fund                   Large Cap  Direct
#
#   Options Riskometer CRISIL_MF_RANK  Sector_Allocation_size     Sector1_Name  \
# 0  Growth          H             NR                       4  Banking/Finance
# 1  Growth         MH              4                      10  Banking/Finance
# 2  Growth          H             NR                       4       Technology
# 3  Growth         MH              5                      10  Banking/Finance
# 4  Growth         MH              1                       8  Banking/Finance
#
#                 ...                Sector6_Percentage  \
# 0               ...                               NaN
# 1               ...                              5.21
# 2               ...                               NaN
# 3               ...                              4.34
# 4               ...                              4.01
#
#                   Sector7_Name  Sector7_Percentage     Sector8_Name  \
# 0                          NaN                 NaN              NaN
# 1  Engineering & Capital Goods                4.53          Tobacco
# 2                          NaN                 NaN              NaN
# 3                Manufacturing                4.06          Tobacco
# 4        Cement & Construction                3.20  Metals & Mining
#
#    Sector8_Percentage   Sector9_Name  Sector9_Percentage  \
# 0                 NaN            NaN                 NaN
# 1                3.94  Manufacturing                3.80
# 2                 NaN            NaN                 NaN
# 3                4.11      Utilities                2.78
# 4                1.32            NaN                 NaN
#
#                  Sector10_Name  Sector10_Percentage  \
# 0                          NaN                  NaN
# 1        Consumer Non-durables                 3.79
# 2                          NaN                  NaN
# 3  Engineering & Capital Goods                 3.12
# 4                          NaN                  NaN
#
#   Total_percentage_of _allocation
# 0                           97.22
# 1                           85.63
# 2                           98.08
# 3                           81.07
# 4                           94.04
#
# [5 rows x 30 columns]
